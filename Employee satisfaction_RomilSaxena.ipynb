# %%
# supress warnings
import warnings
warnings.filterwarnings('ignore')

# Importing all required packages
import numpy as np
import pandas as pd

# Data viz lib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
#Read data
employeeData = pd.read_csv('employee.csv')
employeeData.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
employeeData.info() #Checking for the shape, null values, datatypes of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Filtering All Employees with Attrition = No

# %%
attrNoData = employeeData[(employeeData.Attrition == "No")]

# %%
attrNoData
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ##  Further Filtering all "Attrition = No" employees with condition "BusinessTravel == "Travel_Frequently" as per problem statement

# %%
AttrNoTravelFreq = attrNoData[(attrNoData.BusinessTravel == "Travel_Frequently")]

# %%
AttrNoTravelFreq
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 39     33        No  Travel_Frequently       1141                   Sales
# ...   ...       ...                ...        ...                     ...
# 1418   38        No  Travel_Frequently        508  Research & Development
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Creating 3 Datasets for HR, Sales and R&D department with condition "Attrition = No" & "BusinessTravel == "Travel_Frequently"

# %%
hrEmployees = AttrNoTravelFreq[(AttrNoTravelFreq.Department == "Human Resources")] 
SalesEmployees = AttrNoTravelFreq[(AttrNoTravelFreq.Department == "Sales")]
RnDEmployees = AttrNoTravelFreq[(AttrNoTravelFreq.Department == "Research & Development")]

# %%
hrEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate       Department  \
# 477    50        No  Travel_Frequently       1246  Human Resources
# 923    34        No  Travel_Frequently        648  Human Resources
# 1107   38        No  Travel_Frequently        888  Human Resources
# 1165   44        No  Travel_Frequently        602  Human Resources
# 1245   24        No  Travel_Frequently        897  Human Resources
# 1347   36        No  Travel_Frequently       1213  Human Resources
# 1400   38        No  Travel_Frequently       1444  Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 477                  3          3          Medical              1
# 923                 11          3    Life Sciences              1
# 1107                10          4  Human Resources              1
# 1165                 1          5  Human Resources              1
# 1245                10          3          Medical              1
# ...

# %%
SalesEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 39     33        No  Travel_Frequently       1141      Sales
# 43     27        No  Travel_Frequently        994      Sales
# 48     46        No  Travel_Frequently       1211      Sales
# 56     35        No  Travel_Frequently        853      Sales
# 70     59        No  Travel_Frequently       1225      Sales
# 117    36        No  Travel_Frequently       1467      Sales
# 119    43        No  Travel_Frequently        394      Sales
# 131    50        No  Travel_Frequently        809      Sales
# 144    32        No  Travel_Frequently        689      Sales
# 154    32        No  Travel_Frequently        967      Sales
# 159    34        No  Travel_Frequently        303      Sales
# 212    27        No  Travel_Frequently       1242      Sales
# 226    37        No  Travel_Frequently        319      Sales
# 227    29        No  Travel_Frequently       1413      Sales
# ...

# %%
RnDEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 44     30        No  Travel_Frequently        721  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1409   40        No  Travel_Frequently        692  Research & Development
# 1418   38        No  Travel_Frequently        508  Research & Development
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # 1.

# %% [markdown]
# ## Below are the employees who are from R&D Department and are "Research Scientist"

# %%
RnDResearchScientistiEmployees = RnDEmployees[(RnDEmployees.JobRole == 'Research Scientist')]
RnDResearchScientistiEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 68     35        No  Travel_Frequently        664  Research & Development
# 120    30        No  Travel_Frequently       1312  Research & Development
# 130    43        No  Travel_Frequently        957  Research & Development
# 150    40        No  Travel_Frequently       1395  Research & Development
# 202    34        No  Travel_Frequently        878  Research & Development
# 294    37        No  Travel_Frequently        889  Research & Development
# 332    54        No  Travel_Frequently        928  Research & Development
# 409    42        No  Travel_Frequently        532  Research & Development
# 501    30        No  Travel_Frequently        160  Research & Development
# 519    29        No  Travel_Frequently        806  Research & Development
# ...

# %% [markdown]
# # PS : This Question got changed while the TA sessions were happening.

# %% [markdown]
# # 1

# %% [markdown]
# ## Below are the employees who are from R&D Department and are Research Scientist, PerformanceRating>=3, JobSatisfaction score >=3 and EducationField not in "Life Sciences" & "Medical".

# %%
RnDSelectedEmployees = RnDResearchScientistiEmployees[(RnDResearchScientistiEmployees.PerformanceRating>=3) & (RnDResearchScientistiEmployees.JobSatisfaction>=3) & (RnDResearchScientistiEmployees.EducationField != "Life Sciences") & (RnDEmployees.EducationField != "Medical")]
RnDSelectedEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 765    38        No  Travel_Frequently       1186  Research & Development
# 1168   24        No  Travel_Frequently        567  Research & Development
# 1368   34        No  Travel_Frequently        735  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 765                  3          4             Other              1
# 1168                 2          1  Technical Degree              1
# 1368                22          4             Other              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 765             1060  ...                         1            80
# 1168            1646  ...                         3            80
# 1368            1932  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %% [markdown]
# ## Below is the list of employees who are from R&D Department and are Research Scientist with PerformanceRating>=3, JobSatisfaction score >=3 and EducationField not in "Life Sciences" & "Medical".

# %%
print("Employees with below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company "+'\n')
print ((RnDSelectedEmployees['EmployeeNumber']).to_string(index=False))
# Out:
# Employees with below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company
#
#  1060
#  1646
#  1932

# %% [markdown]
# # 2.

# %% [markdown]
# ## Below are the sales employees whose current JobRole is Sales Executive or Manager.

# %%
SalesExecAndManagers = SalesEmployees[((SalesEmployees.JobRole == 'Sales Executive') | (SalesEmployees.JobRole == 'Manager'))]
SalesExecAndManagers
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 39     33        No  Travel_Frequently       1141      Sales
# 43     27        No  Travel_Frequently        994      Sales
# 48     46        No  Travel_Frequently       1211      Sales
# 56     35        No  Travel_Frequently        853      Sales
# 70     59        No  Travel_Frequently       1225      Sales
# 117    36        No  Travel_Frequently       1467      Sales
# 119    43        No  Travel_Frequently        394      Sales
# 131    50        No  Travel_Frequently        809      Sales
# 144    32        No  Travel_Frequently        689      Sales
# 154    32        No  Travel_Frequently        967      Sales
# 212    27        No  Travel_Frequently       1242      Sales
# 227    29        No  Travel_Frequently       1413      Sales
# 228    35        No  Travel_Frequently        944      Sales
# 282    29        No  Travel_Frequently        442      Sales
# ...

# %% [markdown]
# ## Out of those who work as a Sales Executive or Manager, the company wants to give preference to those who are having PerformanceRating>=3, JobSatisfaction score >=3 and EducationField as "Marketing". On the basis of these conditions, report the shortlisted candidates who can be further interviewed by the company.

# %%
SalesSelectedEmployees = SalesExecAndManagers[(SalesExecAndManagers.PerformanceRating>=3) & (SalesExecAndManagers.JobSatisfaction>=3) & (SalesExecAndManagers.EducationField == "Marketing")]
SalesSelectedEmployees
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 48     46        No  Travel_Frequently       1211      Sales
# 131    50        No  Travel_Frequently        809      Sales
# 154    32        No  Travel_Frequently        967      Sales
# 228    35        No  Travel_Frequently        944      Sales
# 328    33        No  Travel_Frequently        508      Sales
# 576    27        No  Travel_Frequently        829      Sales
# 820    35        No  Travel_Frequently       1182      Sales
# 1051   44        No  Travel_Frequently        383      Sales
# 1319   32        No  Travel_Frequently       1318      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 48                   5          4      Marketing              1
# 131                 12          3      Marketing              1
# 154                  8          3      Marketing              1
# 228                  1          3      Marketing              1
# ...

# %%
print("Below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company "+'\n')
print ((SalesSelectedEmployees['EmployeeNumber']).to_string(index=False))
# Out:
# Below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company
#
#    62
#   174
#   207
#   314
#   446
#   800
#  1137
#  1481
#  1853

# %% [markdown]
# ## Employees with above employee Number satisfies the criteria from Sales Department these employees can be shortlisted for further inteviews.

# %% [markdown]
# # 3

# %% [markdown]
# ## Human Resource: For the HR department, the FreeCell team wants to select the employees who have the best PerformanceRating and JobSatisfaction. Keeping this in mind, report the shortlisted candidates which can be further interviewed by the company.

# %%
hrEmployees.PerformanceRating.max() # Finding the best Performance Rating
# Out:
# 4

# %%
hrEmployees.JobSatisfaction.max() # Finding the best Job Satisfaction
# Out:
# 4

# %% [markdown]
# ## Applying the conditions

# %%
hrSelectedEmployees = hrEmployees.sort_values(['PerformanceRating', 'JobSatisfaction'], ascending=[False, False])
hrSelectedEmployees[['EmployeeNumber','Attrition','BusinessTravel','Department','PerformanceRating','JobSatisfaction']]
# Out:
#       EmployeeNumber Attrition     BusinessTravel       Department  \
# 1347            1890        No  Travel_Frequently  Human Resources
# 1165            1642        No  Travel_Frequently  Human Resources
# 1245            1746        No  Travel_Frequently  Human Resources
# 1107            1563        No  Travel_Frequently  Human Resources
# 477              644        No  Travel_Frequently  Human Resources
# 923             1289        No  Travel_Frequently  Human Resources
# 1400            1972        No  Travel_Frequently  Human Resources
#
#       PerformanceRating  JobSatisfaction
# 1347                  4                4
# 1165                  3                4
# 1245                  3                4
# 1107                  3                3
# 477                   3                2
# 923                   3                2
# 1400                  3                2

# %%
print("Below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company "+'\n')
print ((hrSelectedEmployees['EmployeeNumber']).to_string(index=False))
# Out:
# Below Employee Numbers will be the shortlisted candidates as per criteria who can be further interviewed by the company
#
#  1890
#  1642
#  1746
#  1563
#   644
#  1289
#  1972

# %% [markdown]
# ## Employees with above employee Number in the sorted format top to bottom(desc) satisfies the criteria.
